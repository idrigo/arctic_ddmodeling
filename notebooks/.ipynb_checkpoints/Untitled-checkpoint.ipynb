# %%
# %load_ext autoreload
# %autoreload 2
import sys
import numpy as np
import netCDF4 as nc
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from mpl_toolkits.basemap import Basemap

import matplotlib as mpl
mpl.rcParams['figure.dpi']= 1200
# %matplotlib inline
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [15, 7]
from IPython.display import set_matplotlib_formats
set_matplotlib_formats('retina')

sys.path.append('/Users/drigo/ITMO/_disser/surrogate/src')
from dataset import load_features, load, load_variable_years
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
data = np.load('/Users/drigo/ITMO/_disser/surrogate/data/out3.npy')
ref = nc.Dataset('/Users/drigo/ITMO/_disser/surrogate/data/T_grid_y2010.nc')
global lons, lats
lons = ref.variables['nav_lon'][:]
lats = ref.variables['nav_lat'][:]

# %%
def interp(data, target):
    x = np.arange(0, target.shape[1])
    y = np.arange(0, target.shape[0])
    #mask invalid values
    data = np.ma.masked_invalid(data)
    xx, yy = np.meshgrid(x, y)
    #get only the valid values
    x1 = xx[~data.mask]
    y1 = yy[~data.mask]
    newarr = data[~data.mask]

    GD1 = interpolate.griddata((x1, y1), newarr.ravel(),
                               (xx, yy),
                               method='cubic')
    return GD1

# %%
def plotting(data):
    
    m = Basemap(projection='npstere',boundinglat=70,lon_0=0,resolution='i')

    xi, yi = m(lons_m, lats_m)

    # Add Coastlines, States, and Country Boundaries
    m.fillcontinents(color='grey')
    m.drawmapboundary(fill_color='white')
    m.drawcountries()

    cmap=plt.get_cmap('rainbow')
    cmap.set_bad('white')
    m.pcolormesh(xi, yi, data, cmap=cmap,alpha=1)
    #ndata = RectBivariateSpline(xi,yi,data)
    #m.imshow(x=xi, y=yi, data=data, cmap=cmap,alpha=1)
    #plt.savefig('{}{}.png'.format(pic_dir, fname_out), dpi=600, bbox_inches='tight', pad_inches = 0)
    #plt.clf()

# %%
plotting(data[360,:,:])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-115-ba1bb87d6743> in <module>
# ----> 1 plotting(data[360,:,:])
#
# <ipython-input-114-4427fee8be82> in plotting(data)
#      17     #m.pcolormesh(xi, yi, GD1, cmap=cmap,alpha=1)
#      18     #ndata = RectBivariateSpline(xi,yi,data)
# ---> 19     m.imshow(x=xi, y=yi, data=data, cmap=cmap,alpha=1)
#      20     #plt.savefig('{}{}.png'.format(pic_dir, fname_out), dpi=600, bbox_inches='tight', pad_inches = 0)
#      21     #plt.clf()
#
# ~/anaconda3/envs/disser/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py in imshow(self, *args, **kwargs)
#    3320         self._save_use_hold(ax, kwargs)
#    3321         try:
# -> 3322             ret =  ax.imshow(*args, **kwargs)
#    3323         finally:
#    3324             self._restore_hold(ax)
#
# ...

# %%
interp(data[300, :,:], data[300, :,:])
# Out:
# array([[nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        ...,
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan]])
